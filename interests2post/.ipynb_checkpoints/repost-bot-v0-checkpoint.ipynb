# %%
import os
import re
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import numpy as np
import pandas as pd
import json
import pymorphy2
import nltk
from tqdm import tqdm
from vk_api_dir.vk_api.vk_api_me import API_from_my_data

# %% [markdown]
# - для каждого пользователя скачиваем массив интересов
# - для каждого интереса(слова) приводим его к нормальной форме (например pymorphy)
# - подсчет популярных.

# %%
group = 'okean_music'
api = API_from_my_data.get_api()
# Out:
# password:

# %%
def _parse_and_normalize(s):
    s = nltk.word_tokenize(s)
    morph = pymorphy2.MorphAnalyzer()
    s = [morph.parse(i)[0].normal_form for i in s]
    return s
def check(x):
    return not (x in [u'на', u'под', u'и', u'c', u'в', u'not', u'с'])
def get_n_interests(api, n, group):
    # my api registration
    _dict = api.groups.getMembers(group_id=group)
    count, members = _dict['count'], _dict['users']
    if len(members) >= 1000:
        raise "Not Implemented"
    
    _dict = api.users.get(user_ids=members, fields='interests')
    all_strs = []
    for _ in _dict:
        if 'interests' in _ and len(_['interests']) > 0:
            all_strs.append(_['interests'])
    interest_to_count = dict()
    for _interest in tqdm(np.concatenate([_parse_and_normalize(i) for i in all_strs])):
        if not _interest in interest_to_count:
            interest_to_count[_interest] = 0
        interest_to_count[_interest] += 1
    # костыльно оставляем только слова и сортируем по частоте
    out = sorted(filter(lambda x: x[0].isalpha() and check(x[0]), interest_to_count.items()), key=lambda x: x[1], reverse=True)
    for i in out:    
        print i[0], i[1]
    return map(lambda x: x[0], out[:n])
interests = get_n_interests(api, 10, group)
# Out:
# 100%|██████████| 718/718 [00:00<00:00, 426619.96it/s]
# музыка 17
# кино 8
# любить 5
# фотография 5
# театр 5
# искусство 5
# конкурс 4
# спорт 4
# литература 4
# книга 3
# философия 3
# рукоделие 3
# психология 3
# танец 3
# волейбол 2
# аниме 2
# наука 2
# концерт 2
# интересный 2
# автомобиль 2
# хороший 2
# music 2
# рисование 2
# видеоарт 2
# баскетбол 2
# живопись 2
# слушать 2
# кошка 2
# танцевать 2
# буккроссинг 1
# дождь 1
# фольклор 1
# журналинг 1
# саморазвитие 1
# список 1
# классика 1
# отсутствовать 1
# медицина 1
# прагматизм 1
# посещать 1
# действие 1
# идея 1
# этика 1
# production 1
# общественный 1
# asumiko 1
# алхимия 1
# coffee 1
# рок 1
# график 1
# ведущий 1
# япония 1
# чтение 1
# минимализм 1
# самопознание 1
# скрытый 1
# затягивать 1
# palahniuk 1
# природа 1
# chuck 1
# asano 1
# режим 1
# друг 1
# nakamura 1
# poppy 1
# хотеть 1
# машинка 1
# 明日美子 1
# любовь 1
# нота 1
# brite 1
# art 1
# семья 1
# японский 1
# books 1
# дартс 1
# английский 1
# интернет 1
# ходить 1
# печатный 1
# велосипед 1
# играть 1
# звук 1
# объять 1
# огромный 1
# скука 1
# дизайн 1
# камера 1
# хобби 1
# свой 1
# необъятный 1
# участвовать 1
# воплощение 1
# outfit 1
# самый 1
# составлять 1
# фильм 1
# спать 1
# кинофильм 1
# by 1
# современный 1
# фенёчек 1
# косплей 1
# песнь 1
# знаменитый 1
# туалет 1
# оружие 1
# учёба 1
# inio 1
# техніка 1
# быть 1
# фортепиано 1
# кинология 1
# йог 1
# нравиться 1
# fantasy 1
# 中村 1
# за 1
# следить 1
# your 1
# impressed 1
# взаимодействие 1
# пластический 1
# синтезатор 1
# 浅野いにお 1
# этология 1
# религия 1
# история 1
# помощь 1
# дело 1
# бизнес 1
# педагогика 1
# авторитарный 1
# слэшер 1
# перформанс 1
# ребёнок 1
# мор 1
# футбол 1
# нейронаука 1
# садоводство 1
# дошкольный 1
# политика 1
# нумизматика 1
# не 1
# стаж 1
# готический 1
# иметь 1
# ещё 1
# поэзия 1
# вместе 1
# интерактив 1
# французский 1
# https 1
# кулинария 1
# выставка 1
# писать 1
# из 1
# стих 1
# животное 1
# множество 1
# мероприятие 1
# внук 1
# скрапбукинг 1
# культурный 1
# спектакль 1
# экскурсия 1
# пение 1
# по 1
# компьютер 1
# театральный 1
# фокстерьер 1
# политический 1
# интересоваться 1
# байк 1
# деятельность 1
# познание 1
# говорить 1
# если 1
# символизм 1
# собака 1
# как 1
# тхэквондо 1
# просмотр 1
# i 1
# сила 1
# гора 1
# визуальный 1
# шоколад 1
# дорога 1
# свет 1
# музей 1
# читать 1
# передача 1

# %% [markdown]
# теперь когда мы знаем топ n интересов подписчиков группы, можно взять эти интересы и найти по ним много-много людей, у которых есть свои подписки.
# - берем случайный поднабор интересов и ищем человека
# - получаем группы на которые эти люди подписаны;
# - находим топ k групп, наиболее популярных среди этой подписоты

# %%
import random
import time
import vk

# %%
VkAPIError = vk.exceptions.VkAPIError

# %%
def get_users_by_interests(api, interests, num):
    offs = 0
    persons_found = 0
    NUM_INTERESTS = 5
    users = []
    while persons_found < num:
        #  https://vk.com/dev/users.search
        # берем сколько-то случайных интересов из списка
        curr_interests = [random.choice(interests) for i in range(NUM_INTERESTS)]
        _dict = api.users.search(offset=offs, interests=','.join(curr_interests))
        if _dict[0] + persons_found < num:
            raise Exception("To taught search parameters: only {0} users found".format(_dict[0] + persons_found))
        _dict = _dict[1:]
        persons_found += len(_dict)
        for i in [_usr['uid'] for _usr in _dict]:
            users.append(i)
        time.sleep(1)
    return users
typical_user_ids = get_users_by_interests(api, interests, num=100)
typical_user_ids
# Out:
# [13821502,
#  216970122,
#  346271964,
#  209490370,
#  258468989,
#  29470165,
#  38942884,
#  167041343,
#  92364235,
#  263410754,
#  85599545,
#  181949463,
#  20420307,
#  280153768,
#  203317835,
#  8027438,
#  855775,
#  45854551,
#  189539499,
#  56478071,
#  13821502,
#  216970122,
#  22077894,
#  307134457,
#  346271964,
#  59605782,
#  209490370,
#  258468989,
#  29470165,
#  137735663,
#  68303934,
#  38942884,
#  228929867,
#  181677785,
#  160973233,
#  92364235,
#  244620136,
#  263410754,
#  85599545,
#  360291582,
#  12489927,
#  151576949,
#  11344503,
#  107523643,
#  231817577,
#  68853510,
#  174577275,
#  92528955,
#  193028632,
#  255044186,
#  48393413,
#  314042609,
#  33814534,
#  43053589,
#  102975176,
#  205886807,
#  177028393,
#  402863357,
#  12489927,
#  160489574,
#  20176333,
#  11344503,
#  107523643,
#  194172492,
#  195917130,
#  68853510,
#  174577275,
#  303256288,
#  92528955,
#  13821502,
#  11230885,
#  193028632,
#  255044186,
#  314042609,
#  33814534,
#  43053589,
#  210841413,
#  209452406,
#  231817577,
#  13821502,
#  216970122,
#  22077894,
#  307134457,
#  155446937,
#  252356094,
#  346271964,
#  59605782,
#  209490370,
#  258468989,
#  153581445,
#  287307942,
#  295956145,
#  4609711,
#  88965623,
#  15130019,
#  189967935,
#  210841413,
#  209452406,
#  231817577,
#  13821502,
#  216970122,
#  22077894,
#  307134457,
#  155446937,
#  252356094,
#  346271964,
#  59605782,
#  209490370,
#  258468989,
#  153581445,
#  287307942,
#  295956145,
#  4609711,
#  88965623,
#  15130019,
#  189967935]

# %% [markdown]
# Отлично. Мы получили id пользовательй со схожими интересами. Достанем из подписки и найдем наиболее популярные.

# %%
def get_n_groups_by_ids(api, ids, n=10):
    popular = dict()
    for user_id in tqdm(ids):
        _groups = api.groups.get(user_id=user_id)
        for _group_id in _groups:
            _group_id = int(_group_id)
            if not _group_id in popular:
                popular[_group_id] = 0
            popular[_group_id] += 1
        time.sleep(0.3)
    out = sorted(popular.items(), key=lambda x: x[1], reverse=True)
    return out
popular_groups_ = get_n_groups_by_ids(api, typical_user_ids)
# Out:
# 100%|██████████| 116/116 [00:45<00:00,  2.37it/s]

# %%
popular_groups = popular_groups_[:1000]
# не будем жадничать

# %%
def preprocess(popular_groups):
    good_ = []
    blocked = {12382740, 57846937}
    for group in tqdm(popular_groups):
        if group in blocked:
            continue
        group = group[0]
        #  проверим, что в группе есть посты
        try:
            req_ = api.wall.get(owner_id=group)
            if req_[0] > 10:
                good_.append(group)
        except VkAPIError, Exception:
            continue
    return good_

# %%
checked_groups = preprocess(popular_groups)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 2/1000 [00:00<01:55,  8.62it/s]
#   0%|          | 3/1000 [00:01<06:45,  2.46it/s]
#   0%|          | 5/1000 [00:01<05:18,  3.13it/s]
#   1%|          | 6/1000 [00:01<04:32,  3.65it/s]
#   1%|          | 7/1000 [00:01<03:42,  4.47it/s]
#   1%|          | 10/1000 [00:01<02:47,  5.93it/s]
#   1%|▏         | 13/1000 [00:02<02:08,  7.69it/s]
#   2%|▏         | 16/1000 [00:02<01:40,  9.79it/s]
#   2%|▏         | 19/1000 [00:02<01:21, 12.04it/s]
#   2%|▏         | 22/1000 [00:02<01:16, 12.80it/s]
#   2%|▏         | 24/1000 [00:02<01:24, 11.62it/s]
#   3%|▎         | 27/1000 [00:02<01:09, 13.99it/s]
#   3%|▎         | 29/1000 [00:02<01:10, 13.81it/s]
#   3%|▎         | 32/1000 [00:03<01:01, 15.79it/s]
#   4%|▎         | 35/1000 [00:03<00:54, 17.69it/s]
#   4%|▍         | 38/1000 [00:03<00:51, 18.70it/s]
#   4%|▍         | 41/1000 [00:03<00:46, 20.50it/s]
#   4%|▍         | 44/1000 [00:03<00:48, 19.57it/s]
#   5%|▍         | 47/1000 [00:03<00:45, 21.13it/s]
#   5%|▌         | 50/1000 [00:03<00:42, 22.28it/s]
#   5%|▌         | 53/1000 [00:03<00:41, 23.02it/s]
#   6%|▌         | 56/1000 [00:04<00:40, 23.09it/s]
#   6%|▌         | 59/1000 [00:04<00:38, 24.30it/s]
#   6%|▌         | 62/1000 [00:04<00:38, 24.21it/s]
#   6%|▋         | 65/1000 [00:04<00:39, 23.48it/s]
#   7%|▋         | 68/1000 [00:04<00:41, 22.28it/s]
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/Users/istar/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "
#  87%|████████▋ | 874/1000 [00:40<00:05, 21.71it/s]
#  88%|████████▊ | 877/1000 [00:40<00:05, 22.33it/s]
#  88%|████████▊ | 880/1000 [00:41<00:05, 22.85it/s]
#  88%|████████▊ | 883/1000 [00:41<00:05, 22.93it/s]
#  89%|████████▊ | 886/1000 [00:41<00:04, 23.03it/s]
#  89%|████████▉ | 889/1000 [00:41<00:06, 17.55it/s]
#  89%|████████▉ | 891/1000 [00:41<00:09, 11.99it/s]
#  89%|████████▉ | 893/1000 [00:42<00:09, 11.66it/s]
#  90%|████████▉ | 896/1000 [00:42<00:07, 13.81it/s]
#  90%|████████▉ | 899/1000 [00:42<00:06, 15.62it/s]
#  90%|█████████ | 901/1000 [00:42<00:06, 14.39it/s]
#  90%|█████████ | 903/1000 [00:42<00:06, 15.57it/s]
#  91%|█████████ | 906/1000 [00:42<00:05, 17.88it/s]
#  91%|█████████ | 909/1000 [00:42<00:04, 19.64it/s]
#  91%|█████████ | 912/1000 [00:42<00:04, 21.21it/s]
#  92%|█████████▏| 915/1000 [00:43<00:03, 22.56it/s]
#  92%|█████████▏| 919/1000 [00:43<00:03, 24.87it/s]
#  92%|█████████▏| 922/1000 [00:43<00:02, 26.02it/s]
#  92%|█████████▎| 925/1000 [00:43<00:02, 26.85it/s]
#  93%|█████████▎| 928/1000 [00:43<00:02, 26.94it/s]
#  93%|█████████▎| 931/1000 [00:43<00:02, 26.77it/s]
#  93%|█████████▎| 934/1000 [00:43<00:02, 27.49it/s]
#  94%|█████████▎| 937/1000 [00:43<00:02, 26.80it/s]
#  94%|█████████▍| 940/1000 [00:43<00:02, 26.41it/s]
#  94%|█████████▍| 943/1000 [00:44<00:02, 26.16it/s]
#  95%|█████████▍| 946/1000 [00:44<00:02, 26.65it/s]
#  95%|█████████▍| 949/1000 [00:44<00:01, 26.44it/s]
#  95%|█████████▌| 952/1000 [00:44<00:01, 26.04it/s]
#  96%|█████████▌| 955/1000 [00:44<00:01, 25.22it/s]
#  96%|█████████▌| 958/1000 [00:44<00:02, 19.94it/s]
#  96%|█████████▌| 961/1000 [00:44<00:01, 20.35it/s]
#  96%|█████████▋| 964/1000 [00:44<00:01, 22.12it/s]
#  97%|█████████▋| 967/1000 [00:45<00:01, 23.89it/s]
#  97%|█████████▋| 970/1000 [00:45<00:01, 23.66it/s]
#  97%|█████████▋| 974/1000 [00:45<00:01, 25.81it/s]
#  98%|█████████▊| 977/1000 [00:45<00:00, 26.80it/s]
#  98%|█████████▊| 980/1000 [00:45<00:00, 26.98it/s]
#  98%|█████████▊| 983/1000 [00:45<00:00, 26.75it/s]
#  99%|█████████▊| 986/1000 [00:45<00:00, 26.31it/s]
#  99%|█████████▉| 989/1000 [00:45<00:00, 26.97it/s]
#  99%|█████████▉| 992/1000 [00:46<00:00, 27.20it/s]
# 100%|█████████▉| 995/1000 [00:46<00:00, 26.73it/s]
# 100%|█████████▉| 998/1000 [00:46<00:00, 25.69it/s]
# 100%|██████████| 1000/1000 [00:46<00:00, 21.59it/s]

# %%
len(checked_groups)
# Out:
# 42

# %%
api.groups.getById(group_ids=checked_groups)
# Out:
# [{u'gid': 28556858,
#   u'is_closed': 0,
#   u'name': u'\u0411\u0438\u0437\u043d\u0435\u0441-\u0446\u0438\u0442\u0430\u0442\u043d\u0438\u043a. Online \u0436\u0443\u0440\u043d\u0430\u043b',
#   u'photo': u'https://pp.userapi.com/c837739/v837739806/5e6f/C6WZZu3DUYc.jpg',
#   u'photo_big': u'https://pp.userapi.com/c837739/v837739806/5e6d/jRJvD1aUc8I.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c837739/v837739806/5e6e/vIP-ib2N5cg.jpg',
#   u'screen_name': u'businessquotes',
#   u'type': u'page'},
#  {u'gid': 22079806,
#   u'is_closed': 0,
#   u'name': u'\u041e\u0444\u0438\u0446\u0438\u0430\u043b\u044c\u043d\u044b\u0435 \u0441\u0442\u0440\u0430\u043d\u0438\u0446\u044b \u0412\u041a\u043e\u043d\u0442\u0430\u043a\u0442\u0435',
#   u'photo': u'https://pp.userapi.com/c626619/v626619505/4e428/sxdlBO20DAU.jpg',
#   u'photo_big': u'https://pp.userapi.com/c626619/v626619505/4e422/DeqlD2ua8As.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c626619/v626619505/4e427/H7oOpFLoMwY.jpg',
#   u'screen_name': u'officialpages',
#   u'type': u'page'},
#  {u'gid': 57846937,
#   u'is_closed': 0,
#   u'name': u'MDK',
#   u'photo': u'https://pp.userapi.com/c637721/v637721541/f531b/TdOrJ_w9HLg.jpg',
#   u'photo_big': u'https://pp.userapi.com/c637721/v637721541/f5319/RiwRv2_zRt8.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c637721/v637721541/f531a/5V-vYBtZ5lg.jpg',
#   u'screen_name': u'mudakoff',
#   u'type': u'page'},
#  {u'gid': 12382740,
#   u'is_closed': 0,
#   u'name': u'\u0401\u041f',
#   u'photo': u'https://pp.userapi.com/c837328/v837328577/3fe7e/dkQr0rjE50k.jpg',
#   u'photo_big': u'https://pp.userapi.com/c837328/v837328577/3fe7c/5TqHq0aLTlo.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c837328/v837328577/3fe7d/KuCrL3ArzjY.jpg',
#   u'screen_name': u'fuck_humor',
#   u'type': u'page'},
#  {u'gid': 19542789,
#   u'is_closed': 0,
#   u'name': u'\u0412\u041a\u043e\u043d\u0442\u0430\u043a\u0442\u0435 \u0434\u043b\u044f \u0431\u0438\u0437\u043d\u0435\u0441\u0430',
#   u'photo': u'https://pp.userapi.com/c636416/v636416613/3eaf6/-26wezCOhwU.jpg',
#   u'photo_big': u'https://pp.userapi.com/c636416/v636416613/3eaf3/Z6CC5wKjiK0.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c636416/v636416613/3eaf5/UHSJoXA88qE.jpg',
#   u'screen_name': u'adsnews',
#   u'type': u'page'},
#  {u'gid': 1415705,
#   u'is_closed': 0,
#   u'name': u'\u0422\u0432\u043e\u0440\u0447\u0435\u0441\u043a\u043e\u0435 \u041e\u0431\u044a\u0435\u0434\u0438\u043d\u0435\u043d\u0438\u0435 \xabGazgolder\xbb',
#   u'name': u'\u042f \u0432\u0441\u0435\u0433\u0434\u0430 \u0431\u0443\u0434\u0443 \u0442\u0432\u043e\u0438\u043c \u043f\u043e\u0432\u043e\u0434\u043e\u043c \u043d\u0430\u043f\u0438\u0442\u044c\u0441\u044f.',
#   u'photo': u'https://pp.userapi.com/c636517/v636517421/55aec/uFs-lNrjAQ8.jpg',
#   u'photo_big': u'https://pp.userapi.com/c636517/v636517421/55aea/ckA4p9gBt3w.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c636517/v636517421/55aeb/3AeS36rWAJA.jpg',
#   u'screen_name': u'number1000000',
#   u'type': u'page'},
#  {u'gid': 14087493,
#   u'is_closed': 0,
#   u'name': u'\u041d\u0430 50 \u041e\u0442\u0442\u0435\u043d\u043a\u043e\u0432 \u0422\u0435\u043c\u043d\u0435\u0435',
#   u'photo': u'https://pp.userapi.com/c638427/v638427669/200fb/Wuzvr4M5TZ0.jpg',
#   u'photo_big': u'https://pp.userapi.com/c638427/v638427669/200f9/Igb3ho29aSE.jpg',
#   u'photo_medium': u'https://pp.userapi.com/c638427/v638427669/200fa/wBUTyujYaWU.jpg',
#   u'screen_name': u'50sog',
#   u'type': u'page'}]

# %% [markdown]
# Посчитаем сколько вообще в данной группе набирается лайков в среднем на одну сек времени
# Заодно создадим класс групп vk

# %%
import time
int(time.time())
# Out:
# 1494931104

# %%
class Post:
    def __init__(self, owner_id, post_id, rating):
        self.owner_id = owner_id
        self.post_id = post_id
        self.rating = rating

class Group:
    def __init__(self, api, gid):
        # id группы
        self.gid = gid
        self.api = api
        self.posts = []
        # сколько вообще в данной группе набирается лайков в среднем на одну секунду времени
        self.rating = 0
    
    def get_n_posts(self, n):
        #  обновление данных о постах
        self.time = time.time()
        #  offset = 10 чтобы не брать посты совсем уж без лайков
        #  достаем посты для данной группы
        self.posts = api.wall.get(owner_id=self.gid, count=n, extended=1, filter='owner', version='5.64')['wall']
        self.num, self.posts = self.posts[0], self.posts[1:]
        return len(self.posts) == n
    
    def calc_rate(self, new_posts=True):  #  сколько вообще в данной группе набирается лайков в среднем на одну минуту времени   
        if new_posts:
            self.get_n_posts(10)
        # посчитаем лайки
        mid_ans = 0   
        for i in self.posts:
            LIKES = int(i['likes']['count'])
            mid_ans += LIKES / (self.time - i['date'])
            #  it's needed
            time.sleep(0.3)
        mid_ans /= len(self.posts)  
        self.rating = mid_ans
        return self.rating != 0
    def calc_post_rating(self, post, rating):
        likes_cnt = int(post['likes']['count'])
        rate = likes_cnt / (self.time - post['date'])
        return rate / rating
    def get_rated_posts(self):
        # get posts from group and evaluate them
        posts = []
        for post in self.posts:
            post_rating = self.calc_post_rating(post, self.rating)
            posts.append(Post(self.gid, post['id'], post_rating))
        return posts

# %%
api.wall.get(owner_id="-57846937", count=2, extended=1, filter='owner', version='5.64')['wall'][1]['id']
# Out:
# 13597739

# %%
buisness = Group(api, "-57846937")
buisness.get_n_posts(10)
# вычисляем рейтинг группы по хранящимся у нас постам
buisness.calc_rate()
rated_posts = buisness.get_rated_posts()

# %%
#  например можно посмотреть рейтинг конкретного поста
print "Post id = {}, rating = {}".format(rated_posts[1].post_id, rated_posts[1].rating)
print "Post id = {}, rating = {}".format(rated_posts[3].post_id, rated_posts[3].rating)
# Out:
# Post id = 13628397, rating = 0.532051435711
# Post id = 13626584, rating = 0.906419222954

# %% [markdown]
# теперь на напишем класс Robot, который будучи запущенным будет реализовывать интерфейс подписки на выбранные нами паблики
#
# Важно не словить 'VkAPIError'!

# %% [markdown]
# Необходимый функционал:
# - [получить](https://vk.com/dev/wall.get) свежие посты из группы
# - [получить](https://vk.com/dev/likes.getList) число лайков -> рейтинг
# - [репостнуть](https://vk.com/dev/wall.repost)

# %%
checked_groups
# Out:
# [28556858,
#  22079806,
#  57846937,
#  12382740,
#  19542789,
#  1415705,
#  34384434,
#  31976785,
#  36775802,
#  34300760,
#  38119975,
#  30525261,
#  39043096,
#  32231484,
#  28458350,
#  68263002,
#  47029734,
#  4093705,
#  15106510,
#  19799369,
#  64628087,
#  51034455,
#  25740422,
#  35179056,
#  40684908,
#  33913959,
#  32866108,
#  103027469,
#  40115848,
#  36736385,
#  40800148,
#  45799434]

# %%
class Poster:
    def __init__(self, receiver, post):
        self.post = post
        self.group = receiver
        
class Robot:
    def __init__(self, api, groups):
        """
        api: vkapi session
        groups: Group class'
        
        Class Robot takes Posts from Groups 
        and chose the best Post via comparator 
        and repost this Post in chosen user's group via Poster
        """
        self.api = api
        if len(groups) > 50:
            raise Exception("Too much...")
        self.groups = []
        for g_id in groups:
            self.groups.append(Group(api, g_id))
    def get_all_rated_posts(self):
        self.rated_posts = []
        for group in self.groups:
            if group.get_n_posts(10):
                group.calc_rate()
                self.rated_posts.append(group.get_rated_posts())
                print "OK"
            print ":("
    def get_max_rated_post(self):
        self.get_all_rated_posts()
        print self.rated_posts
        mx_ans = [-1, -1]
        for batch in self.rated_posts:
            mx = max(batch, key=lambda x: x[1])
            mx_ans = max(mx, mx_ans, key=lambda x: x[1])
        return mx_ans
    

r = Robot(api, checked_groups)   
r.get_max_rated_post()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-268-02f013317f33> in <module>()
#      37
#      38 r = Robot(api, checked_groups)
# ---> 39 r.get_max_rated_post()
#
# <ipython-input-268-02f013317f33> in get_max_rated_post(self)
#      27                 self.rated_posts.append(group.get_rated_posts())
#      28     def get_max_rated_post(self):
# ---> 29         self.get_all_rated_posts()
#      30         print self.rated_posts
#      31         mx_ans = [-1, -1]
#
# <ipython-input-268-02f013317f33> in get_all_rated_posts(self)
#      25             if group.get_n_posts(10):
#      26                 group.calc_rate()
# ---> 27                 self.rated_posts.append(group.get_rated_posts())
#      28     def get_max_rated_post(self):
#      29         self.get_all_rated_posts()
#
# <ipython-input-264-d821548e1d39> in get_rated_posts(self)
#      44         posts = []
#      45         for post in self.posts:
# ---> 46             post_rating = self.calc_post_rating(post, self.rating)
#      47             posts.append(Post(self.gid, post['id'], post_rating))
#      48         return posts
#
# <ipython-input-264-d821548e1d39> in calc_post_rating(self, post, rating)
#      39         likes_cnt = int(post['likes']['count'])
#      40         rate = likes_cnt / (self.time - post['date'])
# ---> 41         return rate / rating
#      42     def get_rated_posts(self):
#      43         # get posts from group and evaluate them
#
# ZeroDivisionError: float division by zero
