# %%
# -*- coding: utf-8 -*-
from urllib2 import urlopen
from lxml import etree
import urllib
from lxml import html
from bs4 import BeautifulSoup
import io
import pandas as pd
from io import StringIO, BytesIO
import pandas as pd
import numpy as np
import re
from collections import deque
import json
import urllib2

# %%
import pandas as pd
url = "https://www.avito.ru/moskva/tovary_dlya_kompyutera/komplektuyuschie/videokarty?p=2"
page = urllib.urlopen(url).read()
soup = BeautifulSoup(page, 'html.parser')

# %%
for item in soup.find_all("div", class_="item"):
    for s in item.find_all('div', class_="description"):
        lnk = s.find('a', class_="item-description-title-link")
        print "LINK: " +  lnk['href']
        print(lnk['title'])
    print('---\n\n')
# Out:
# LINK: /moskva/tovary_dlya_kompyutera/asus_gigabyte_palit_gtx_770_2_gb_919312082
# Asus gigabyte Palit gtx 770 2 GB в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/fermy_dlya_mayninga_8_rx_480_270_mh_na_efire_987446562
# Фермы для майнинга 8 rx 480 270 MH на эфире в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/gigabyte_asus_msi_gtx_660_1010571671
# Gigabyte asus MSI GTX 660 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/gtx_580_1213069469
# GTX 580 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/prodaetsya_videokarta_radeon_9800_se_128_m_674435842
# Продается видеокарта Radeon 9800 se 128 m в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/graficheskiy_adapter_terratec_connect_a1_657978919
# Графический адаптер Terratec Connect A1 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_asus_v9280stvd128m_1125051378
# Видеокарта asus V9280S/TVD/128M в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_radeon_9000_pro_sapphire_1003173165
# Видеокарта: Radeon 9000 pro sapphire в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_geforce_6600gt_1181443306
# Видеокарта GeForce 6600GT в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_1014459644
# Видеокарта в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/2_shtuki_geforce_gtx_295_prodayu_menyayu_801112596
# 2 штуки GeForce GTX 295 продаю меняю в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_sapphire_radeon_hd_4730_512_mb_1180422323
# Видеокарта Sapphire radeon HD 4730 512 Мб в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_1174599140
# Видеокарта в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/gtx_760_562563160
# GTX 760 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/geforce_msi_gtx1070_gamingx_8g_1075897990
# GeForce MSI GTX1070 GamingX 8g в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/novaya_asus_geforce_gt_730_1011100393
# Новая asus geforce gt 730 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/palit_geforce_8500_gt_sonic_256mb_dvi_pci-e_1122065023
# Palit GeForce 8500 GT Sonic 256Mb DVI PCI-E в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/sapphire_radeon_hd_2600_pro_600mhz_pci-e_512mb_770215880
# Sapphire Radeon HD 2600 Pro 600Mhz PCI-E 512Mb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/igrovaya_videokarta_msi_r9_280x_gaming_3g_914149352
# Игровая видеокарта MSI R9 280x gaming 3g в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/geforce_gtx960_4_gb_1087907301
# Geforce GTx960 4 Gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_geforce4_mx_440_64mb_agp8x_905507383
# Видеокарта GeForce4 MX 440 64MB AGP8X в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_gtx_750_ti_1122911654
# Видеокарта GTX 750 ti в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/asus_radeon_hd_2600512m_1211708281
# Asus Radeon HD 2600/512M в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/msi_8600_gts_512_mb_888689001
# MSI 8600 GTS 512 mb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/asus_gtx660_ti-dc2oc-3gd5_1006_mgts_videokarta_795877532
# Asus GTX660 TI-DC2OC-3GD5 1006 мгц видеокарта в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_gigabyte_gv-n460so-1gi_857516428
# Видеокарта gigabyte GV-N460SO-1GI в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/radeon_sapphire_rx470_nitro_4gb_1078984006
# Radeon Sapphire RX470 Nitro+ 4GB в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/sapphire_amd_r9_270_2048mb_256b_1051753419
# Sapphire AMD R9 270 2048Mb 256b в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/nvidia_gtx_1080_founders_edition_8gb_1140787570
# Nvidia GTX 1080 Founders edition 8Gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/gigabyte_gv-n1080xtreme-8gdn_1057309932
# Gigabyte GV-N1080xtreme-8GDN в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/prodam_sapphire_radeon_6450_novaya_na_garantii_1025317738
# Продам Sapphire Radeon 6450 новая на гарантии в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/plata_videonablyudeniya_ildvr_3000h4c_8_kanalov_962400405
# Плата видеонаблюдения ildvr 3000H4C 8 каналов в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/plata_videonablyudeniya_ildvr_3000h4c_4_kanala_957212024
# Плата видеонаблюдения ildvr 3000H4C 4 канала в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/asus_gt610-sl-1gd3-l_918901139
# Asus gt610-sl-1gd3-l в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/blackmagic_decklink_studio_plata_zahvata_1133784961
# Blackmagic decklink studio плата захвата в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/geforce_gt625_2gb_ddr3_1110239903
# GeForce GT625 2gb DDR3 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/gigabyte_gt_220_1218342626
# Gigabyte gt 220 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/r9_380_msi_4gb_880392857
# R9 380 MSI 4gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/palit_hd4870_1148557331
# Palit HD4870 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/zotac_geforce_gtx_690_1143447212
# Zotac Geforce gtx 690 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarty_dlya_imac_21.5_24_27_a1312_2008-2011_917872300
# Видеокарты для iMac 21.5" 24" 27" A1312 2008-2011 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_msi_gtx_760_2gb_1197320470
# Видеокарта MSI GTX 760 2GB в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/voodoo_5_5500_agp_1188923580
# Voodoo 5 5500 AGP в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_gainward_geforce_nvidia_gtx_260_943020118
# Видеокарта Gainward Geforce Nvidia GTX 260 в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/msi_gtx980_gaming_4g_1095497060
# MSI GTX980 Gaming 4G в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/palit_gtx_1060_dual_6gb_1050918053
# Palit GTX 1060 Dual 6Gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/palit_gtx_1060_super_jetstream_6gb_930692275
# Palit GTX 1060 Super Jetstream 6Gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/palit_gtx_1070_super_jetstream_8gb_930237191
# Palit GTX 1070 Super Jetstream 8Gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/palit_gtx_1070_jetstream_8gb_915868298
# Palit GTX 1070 Jetstream 8Gb в Москве
# ---
#
#
# LINK: /moskva/tovary_dlya_kompyutera/videokarta_msi_gtx1070_8gb_1048186913
# Видеокарта MSI GTX1070 8Gb в Москве
# ---

# %%
def save_ad_phone_image(ad_id, ad_image_hash):
        ad_image_file = open('%s' % ad_id, "wb")
        ad_image_file.write(ad_image_hash.decode('base64'))
        ad_image_file.close()
        
class PageParser():
    """
    example page: https://www.avito.ru/moskva/tovary_dlya_kompyutera/nvidia_gtx_1080_amd_radeon_r9_270x_i_drugie_modeli_728193995
    extract:
        phone
        text description
        adress
        name
        price
        how to use: 
        >> parser = PageParser(url)
        >> parser.get_user_name()
    """
    description = None
    price = None
    def __init__(self, url):
        self.url = url #!!!!
        self.page = urllib.urlopen(self.url).read()
        self.soup = BeautifulSoup(self.page, 'html.parser')
    def find_price(self):
        return self.get_variable('avito.item.price')
    def get_title(self):
        tag_ = self.soup.find('div', class_="sticky-header-prop")
        return tag_.text.strip()
    def find_text_description(self):
        tag_ = self.soup.find('meta', attrs={"property" : "og:description"})
        self.description = tag_["content"]
        return self.description
    def find_id_number(self):
        tag_ = self.soup.find('div', class_='title-info-metadata-item')
        self.id_number = tag_.text
        self.id_number = self.get_number_from_str(self.id_number)
        return self.id_number
    def get_number_from_str(self, s):
        # переписать нормально мб
        while (not re.match('[0-9]', s[0])):
            s = s[1:]
        ans = ""
        i = 0
        while (re.match('[0-9]', s[i:])):
            i += 1
        return s[:i]
    # get image url by pkey and ID
    def get_image_pkey(self, ad_id=False, ad_phone=False):
        if ad_id and ad_phone:
            ad_subhash = re.findall(r'[0-9a-f]+', ad_phone)
            if int(ad_id) % 2 == 0:
                ad_subhash.reverse()
            ad_subhash = ''.join(ad_subhash)
            return ad_subhash[::3]
    def get_phone_json(self, id_, pkey_, sHash_, url_):
        req = "https://www.avito.ru/items/phone/{0}?pkey={1}&vsrc=r&searchHash={2}".format(id_, pkey_, sHash_)
        ref = 'https://www.avito.ru' + url_
        request = urllib2.Request(req, headers={'Referer': ref})
        response = urllib2.urlopen(request)
        html = response.read()
        return html
    def get_variable(self, s):
        pre = re.compile(s + " = '(.*)';")    
        scripts = self.soup.find_all('script')
        answer = ""
        for i in scripts:
            try:
                ans = re.findall(pre, i.string)
                if len(ans) != 0:
                    answer = ans[0].strip()
            except:
                pass
        return answer   
    def get_ad_phone_hash(self):
        return self.get_variable('avito.item.phone')
    
    def get_avito_item_searchHash(self):
        return self.get_variable('avito.item.searchHash')
    
    def get_avito_item_id(self):
        return self.get_variable('avito.item.id')
    
    def get_user_name(self):
        # <div class="seller-info-name">
        tag_ = self.soup.find('div', class_='seller-info-name')
        return tag_.text.strip()
    
    def get_user_adress(self):
        tags = self.soup.find_all('div', class_='seller-info-prop')
        for i in tags:
            tg = i.find('div', class_='seller-info-label')
            if (tg.text == u'Адрес'):
                return i.find('div', class_='seller-info-value').text.strip()
        return "NONE"
    
    def get_phone_image(self):
        id_ = str(self.get_avito_item_id())
        phone_ = self.get_ad_phone_hash()
        pkey_ = self.get_image_pkey(id_, phone_)
        url_ = self.get_variable('avito.item.url')
        json = self.get_phone_json(id_, pkey_, self.get_avito_item_searchHash(), url_)
        self.json = json
        return self.json
    
    def save_image(self):
        ss = json.loads(self.get_phone_image())['image64']
        image = ss[ss.find(','):]
        save_ad_phone_image(parser.get_avito_item_id(), image)
    ################################
    #       mobile version         #
    ################################
    def get_phone_mobile(self, Hash_, url_):
        req = 'https://m.avito.ru' + url_ + '?async&searchHash=' + Hash_
        ref = 'https://m.avito.ru' + url_
        request = urllib2.Request(req, headers={'Referer': ref})
        response = urllib2.urlopen(request)
        html = response.read()
        return html
    def get_phone_from_mobile(self):
        hash_ = self.get_avito_item_searchHash()
        """class="person-action button button-solid button-blue button-large action-link link action-show-number
        js-action-show-number  "
        href="/moskva/predlozheniya_uslug/arenda_avtovyshki_15m_801012276/phone/3f124991e8b0dbb97b7c025c46b1fe6f"
        """
        tag_ = self.soup.find('a', class_="action-show-number")
        url_ = tag_['href']
        json_ = self.get_phone_mobile(hash_, url_)
        return json.loads(json_)['phone']

# %%
class Data:
    def __init__(self):
        """
        create a deque which is trying to get-and-scrap pages by url from Avito
        extracts data from pages via PageParser and return DataFrame object
        NOTE blocked if using with same ip non-stop more then 10 times (10 links)
        """
        self.index = 0
        self.links = deque()
        self.descriptions = deque()
        self.prices = deque()
        self.mobiles = deque()
        self.user_names = deque()
        self.adresses = deque()
        self.titles = deque()
    def add_link(self, lnk):
        self.links.append(lnk)
    def parse_next(self):
        # full
        parser = PageParser(self.links[self.index])
        self.descriptions.append(parser.find_text_description())
        self.prices.append(parser.find_price())
        self.user_names.append(parser.get_user_name())
        self.adresses.append(parser.get_user_adress())
        self.titles.append(parser.get_title())
        # mobile
        parser = PageParser(self.links[self.index].replace('www', 'm'))
        self.mobiles.append(parser.get_phone_from_mobile())
        self.index += 1
    def get_DataFrame(self):
        d = {'title' : self.titles, 'Price' : self.prices, 'Description' : self.descriptions, 'phone' : self.mobiles, 
            'name' : self.user_names, 'adress' : self.adresses}
        return pd.DataFrame(data=d)

# %%
data = Data()

# %% [markdown]
# Extract pages and data in data = Data()

# %%
url = "https://www.avito.ru/moskva/avtomobili/vaz_lada?f=188_6045b.1375_0b15505"
page = urllib.urlopen(url).read()
soup = BeautifulSoup(page, 'html.parser')
data = Data()
lnk_counter = 0
for item in soup.find_all("div", class_="item"):
    for s in item.find_all('div', class_="description"):
        try:
            lnk = s.find('a', class_="item-description-title-link")
            #  print "LINK: " +  lnk['href']
            #  print(lnk['title'])
            url_page = 'https://www.avito.ru' + lnk['href']
            # print(url_page)
            data.add_link('https://www.avito.ru' + lnk['href'])
            data.parse_next()
            break
        except:
            break
    lnk_counter += 1
    if (lnk_counter > 1):
        break
    time.sleep(10)
    print(lnk_counter)
    full_data = data
    #  print('---\n\n')
# Out:
# 1

# %%
autos = data.get_DataFrame()
autos
# Out:
#                                          Description   Price  \
# 0  Машина находится в салоне по адресу Автомобиль...  449900
# 1  На Lada Granta действуют специальные условия! ...  322000
#
#                            adress               name            phone  \
# 0  Москва, ул. Сормовская, д. 21а         АвтоГЕРМЕС  8 495 663-19-96
# 1                          Москва  Автомобильный Дом  8 499 322-25-14
#
#                title
# 0  LADA Priora, 2016
# 1  LADA Granta, 2016

# %%
autos.sort_values(by='Price')
# Out:
#                                          Description   Price  \
# 1  На Lada Granta действуют специальные условия! ...  322000
# 0  Машина находится в салоне по адресу Автомобиль...  449900
#
#                            adress               name            phone  \
# 1                          Москва  Автомобильный Дом  8 499 322-25-14
# 0  Москва, ул. Сормовская, д. 21а         АвтоГЕРМЕС  8 495 663-19-96
#
#                title
# 1  LADA Granta, 2016
# 0  LADA Priora, 2016

# %%
method(local = True)
